# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ref_2013 = pd.read_csv('refugiados_2013.csv')

# %%
ref_2013.rename(columns={'SOLICITANTES':'SOLICITANTES13', 'ABANDONOS':'ABANDONOS13', 'DESISTIDOS':'DESISTIDOS13', 'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO':'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO13', 'RECONOCIDOS':'RECONOCIDOS13', 'PC':'PC13', 'NO RECONOCIDOS':'NO RECONOCIDOS13'}, inplace=True)

# %%
ref_2013
# Out:
#                PAÍS  SOLICITANTES13  ABANDONOS13  DESISTIDOS13  \
# 0          HONDURAS             530           84            78
# 1          SALVADOR             309           46            31
# 2              CUBA              98            4            55
# 3             INDIA              87            1            74
# 4         GUATEMALA              48           15             2
# 5          COLOMBIA              40           10             1
# 6           NIGERIA              39            1             2
# 7         NICARAGUA              20           11             4
# 8             HAITI              14            2             3
# 9             GHANA              12            1             6
# 10            SIRIA              11            0             0
# 11       BANGLADESH               9            0             9
# 12   ESTADOS UNIDOS               7            0             0
# 13          CAMERUN               6            0             1
# ...

# %%
ref_2017= pd.read_csv('refugiados_2017.csv')

# %%
ref_2017.head()
# Out:
#         PAÍS  SOLICITANTES  ABANDONOS  DESISTIDOS  CANCELACIÓN DE REFUGIO  \
# 1   HONDURAS          4272        706          68                       0
# 2  VENEZUELA          4042         49          14                       0
# 3   SALVADOR          3708        516          29                       0
# 4       CUBA           796        510           9                       0
# 5  GUATEMALA           676        128           4                       0
#
#    EN TRÁMITE  SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO  RECONOCIDOS   PC  \
# 1        1960                                        1537          378  392
# 2        3067                                         912          907    0
# 3        1654                                        1509          525  441
# 4         124                                         153           17    6
# 5         305                                         239           55   68
#
#    NO RECONOCIDOS
# 1           767.0
# 2             5.0
# ...

# %%
ref_2017.rename(columns={'SOLICITANTES':'SOLICITANTES17', 'ABANDONOS':'ABANDONOS17', 'DESISTIDOS':'DESISTIDOS17','CANCELACIÓN DE REFUGIO':'CANCELACIÓN DE REFUGIO17','EN TRÁMITE':'EN TRÁMITE17', 'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO':'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO17', 'RECONOCIDOS':'RECONOCIDOS17', 'PC':'PC17', 'NO RECONOCIDOS':'NO RECONOCIDOS17'}, inplace=True)

# %%
ref_2014 = pd.read_csv('refugiados_2014.csv')

# %%
ref_2014.rename(columns={'SOLICITANTES':'SOLICITANTES14', 'ABANDONOS':'ABANDONOS14', 'DESISTIDOS':'DESISTIDOS14', 'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO':'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO14', 'RECONOCIDOS':'RECONOCIDOS14', 'PC':'PC14', 'NO RECONOCIDOS':'NO RECONOCIDOS14'}, inplace=True)

# %%
ref_2014
# Out:
#                PAÍS  SOLICITANTES14  ABANDONOS14  DESISTIDOS14  \
# 0          HONDURAS            1035          228           148
# 1          SALVADOR             626          105            70
# 2         GUATEMALA             108           22            16
# 3              CUBA              96           11            77
# 4         VENEZUELA              56            0             0
# 5          COLOMBIA              31            2             5
# 6             INDIA              30            0            23
# 7         NICARAGUA              28            9             5
# 8             HAITI              25            1             4
# 9           NIGERIA              14            4             0
# 10   ESTADOS UNIDOS              10            3             1
# 11          UCRANIA               9            0             0
# 12            NEPAL               8            0             8
# 13       BANGLADESH               6            0             6
# ...

# %%
ref_2015 = pd.read_csv('refugiados_2015.csv')

# %%
ref_2015.rename(columns={'SOLICITANTES':'SOLICITANTES15', 'ABANDONOS':'ABANDONOS15', 'DESISTIDOS':'DESISTIDOS15', 'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO':'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO15', 'RECONOCIDOS':'RECONOCIDOS15', 'PC':'PC15', 'NO RECONOCIDOS':'NO RECONOCIDOS15'}, inplace=True)

# %%
ref_2015.head()
# Out:
#         PAIS  SOLICITANTES15  ABANDONOS15  DESISTIDOS15  \
# 0   HONDURAS            1560          348           157
# 1   SALVADOR            1476          251           137
# 2  GUATEMALA             102           28             5
# 3  VENEZUELA              57            4             0
# 4       CUBA              37            7            23
#
#    SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO15  RECONOCIDOS15  PC15  \
# 0                                          1055            379    70
# 1                                          1088            474    69
# 2                                            69             27     7
# 3                                            53             26     8
# 4                                             7              1     0
#
#    NO RECONOCIDOS15
# 0               606
# 1               545
# 2                35
# 3                19
# 4                 6

# %%
ref_2015.rename(columns={'PAIS': 'PAÍS'}, inplace=True)

# %%
ref_2016 = pd.read_csv('refugiados_2016.csv')

# %%
ref_2016.rename(columns={'SOLICITANTES':'SOLICITANTES16', 'ABANDONOS':'ABANDONOS16', 'DESISTIDOS':'DESISTIDOS16', 'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO':'SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO16', 'RECONOCIDOS':'RECONOCIDOS16', 'PC':'PC16', 'NO RECONOCIDOS':'NO RECONOCIDOS16'}, inplace=True)

# %%
ref_2016
# Out:
#                   PAÍS  SOLICITANTES16  ABANDONOS16  DESISTIDOS16  \
# 0             HONDURAS            4129         1053           157
# 1             SALVADOR            3493          860           103
# 2            GUATEMALA             437           96            12
# 3            VENEZUELA             361           11             2
# 4            NICARAGUA              70           16             5
# 5                HAITI              47           19             4
# 6             COLOMBIA              44            6             0
# 7                 CUBA              43           21             9
# 8              CAMERUN              23            9             7
# 9              ECUADOR              20           11             5
# 10               GHANA              16            0             0
# 11      ESTADOS UNIDOS              15            3             0
# 12             ALBANIA               9            2             0
# ...

# %%
#pd.merge(names, info, how='outer')

total_ref = pd.merge(ref_2013, ref_2014, how='outer', on='PAÍS')
total_ref


#a = pd.merge(names, info, how='left', on='names')
# Out:
#                PAÍS  SOLICITANTES13  ABANDONOS13  DESISTIDOS13  \
# 0          HONDURAS           530.0         84.0          78.0
# 1          SALVADOR           309.0         46.0          31.0
# 2              CUBA            98.0          4.0          55.0
# 3             INDIA            87.0          1.0          74.0
# 4         GUATEMALA            48.0         15.0           2.0
# 5          COLOMBIA            40.0         10.0           1.0
# 6           NIGERIA            39.0          1.0           2.0
# 7         NICARAGUA            20.0         11.0           4.0
# 8             HAITI            14.0          2.0           3.0
# 9             GHANA            12.0          1.0           6.0
# 10            SIRIA            11.0          0.0           0.0
# 11       BANGLADESH             9.0          0.0           9.0
# 12   ESTADOS UNIDOS             7.0          0.0           0.0
# 13          CAMERUN             6.0          0.0           1.0
# ...

# %%
total_ref = pd.merge(total_ref, ref_2015, how='outer', on='PAÍS')
total_ref
# Out:
#                PAÍS  SOLICITANTES13  ABANDONOS13  DESISTIDOS13  \
# 0          HONDURAS           530.0         84.0          78.0
# 1          SALVADOR           309.0         46.0          31.0
# 2              CUBA            98.0          4.0          55.0
# 3             INDIA            87.0          1.0          74.0
# 4         GUATEMALA            48.0         15.0           2.0
# 5          COLOMBIA            40.0         10.0           1.0
# 6           NIGERIA            39.0          1.0           2.0
# 7         NICARAGUA            20.0         11.0           4.0
# 8             HAITI            14.0          2.0           3.0
# 9             GHANA            12.0          1.0           6.0
# 10            SIRIA            11.0          0.0           0.0
# 11       BANGLADESH             9.0          0.0           9.0
# 12   ESTADOS UNIDOS             7.0          0.0           0.0
# 13          CAMERUN             6.0          0.0           1.0
# ...

# %%
total_ref = pd.merge(total_ref, ref_2016, how='outer', on='PAÍS')
total_ref
# Out:
#                   PAÍS  SOLICITANTES13  ABANDONOS13  DESISTIDOS13  \
# 0             HONDURAS           530.0         84.0          78.0
# 1             SALVADOR           309.0         46.0          31.0
# 2                 CUBA            98.0          4.0          55.0
# 3                INDIA            87.0          1.0          74.0
# 4            GUATEMALA            48.0         15.0           2.0
# 5             COLOMBIA            40.0         10.0           1.0
# 6              NIGERIA            39.0          1.0           2.0
# 7            NICARAGUA            20.0         11.0           4.0
# 8                HAITI            14.0          2.0           3.0
# 9                GHANA            12.0          1.0           6.0
# 10               SIRIA            11.0          0.0           0.0
# 11          BANGLADESH             9.0          0.0           9.0
# 12      ESTADOS UNIDOS             7.0          0.0           0.0
# ...

# %%
total_ref = pd.merge(total_ref, ref_2017, how='outer', on='PAÍS')
total_ref
# Out:
#                                PAÍS  SOLICITANTES13  ABANDONOS13  \
# 0                          HONDURAS           530.0         84.0
# 1                          SALVADOR           309.0         46.0
# 2                              CUBA            98.0          4.0
# 3                             INDIA            87.0          1.0
# 4                         GUATEMALA            48.0         15.0
# 5                          COLOMBIA            40.0         10.0
# 6                           NIGERIA            39.0          1.0
# 7                         NICARAGUA            20.0         11.0
# 8                             HAITI            14.0          2.0
# 9                             GHANA            12.0          1.0
# 10                            SIRIA            11.0          0.0
# 11                       BANGLADESH             9.0          0.0
# 12                   ESTADOS UNIDOS             7.0          0.0
# ...

# %%
total_ref.dtypes
# Out:
# PAÍS                                             object
# SOLICITANTES13                                  float64
# ABANDONOS13                                     float64
# DESISTIDOS13                                    float64
# SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO13    float64
# RECONOCIDOS13                                   float64
# PC13                                            float64
# NO RECONOCIDOS13                                float64
# SOLICITANTES14                                  float64
# ABANDONOS14                                     float64
# DESISTIDOS14                                    float64
# SOLICITANTES QUE CONCLUYERON PROCEDIMIENTO14    float64
# RECONOCIDOS14                                   float64
# PC14                                            float64
# NO RECONOCIDOS14                                float64
# SOLICITANTES15                                  float64
# ABANDONOS15                                     float64
# ...

# %%
#df[1].fillna(0, inplace=True)

total_ref.fillna(0, inplace=True)

# %%
total_ref['Total_sum_sol'] = total_ref['SOLICITANTES13'] + total_ref['SOLICITANTES14'] + total_ref['SOLICITANTES15'] + total_ref['SOLICITANTES16'] + total_ref['SOLICITANTES17']

# %%
total_ref.drop(total_ref.index[89], inplace=True)

# %%
total_ref
# Out:
#                                PAÍS  SOLICITANTES13  ABANDONOS13  \
# 0                          HONDURAS           530.0         84.0
# 1                          SALVADOR           309.0         46.0
# 2                              CUBA            98.0          4.0
# 3                             INDIA            87.0          1.0
# 4                         GUATEMALA            48.0         15.0
# 5                          COLOMBIA            40.0         10.0
# 6                           NIGERIA            39.0          1.0
# 7                         NICARAGUA            20.0         11.0
# 8                             HAITI            14.0          2.0
# 9                             GHANA            12.0          1.0
# 10                            SIRIA            11.0          0.0
# 11                       BANGLADESH             9.0          0.0
# 12                   ESTADOS UNIDOS             7.0          0.0
# ...

# %%
total_ref.drop(total_ref.index[44], inplace=True)

# %%
total_ref.sort_values(by='Total_sum_sol', ascending=False)
# Out:
#                                PAÍS  SOLICITANTES13  ABANDONOS13  \
# 0                          HONDURAS           530.0         84.0
# 1                          SALVADOR           309.0         46.0
# 42                        VENEZUELA             1.0          0.0
# 4                         GUATEMALA            48.0         15.0
# 2                              CUBA            98.0          4.0
# 68                            HAITÍ             0.0          0.0
# 5                          COLOMBIA            40.0         10.0
# 7                         NICARAGUA            20.0         11.0
# 12                   ESTADOS UNIDOS             7.0          0.0
# 3                             INDIA            87.0          1.0
# 69                          CAMERÚN             0.0          0.0
# 8                             HAITI            14.0          2.0
# 70                           ISRAEL             0.0          0.0
# ...

# %%
total_ref.to_csv('total_solicitudes.csv', index=False)

# %%
new_ref= total_ref.filter(["PAÍS", "SOLICITANTES13", "SOLICITANTES14", "SOLICITANTES15", "SOLICITANTES16", "SOLICITANTES17"], axis=1)

# %%
new_ref
# Out:
#                                PAÍS  SOLICITANTES13  SOLICITANTES14  \
# 0                          HONDURAS           530.0          1035.0
# 1                          SALVADOR           309.0           626.0
# 2                              CUBA            98.0            96.0
# 3                             INDIA            87.0            30.0
# 4                         GUATEMALA            48.0           108.0
# 5                          COLOMBIA            40.0            31.0
# 6                           NIGERIA            39.0            14.0
# 7                         NICARAGUA            20.0            28.0
# 8                             HAITI            14.0            25.0
# 9                             GHANA            12.0             3.0
# 10                            SIRIA            11.0             6.0
# 11                       BANGLADESH             9.0             6.0
# 12                   ESTADOS UNIDOS             7.0            10.0
# ...

# %%
new_ref.to_csv('solicitudes_por_anio.csv', index=False)

# %%
df = pd.read_csv("solicitudes_por_anio.csv")

# %%
df
# Out:
#                                        COUNTRY  SOLICITANTES13  \
# 0                                     Honduras           530.0
# 1                                  El Salvador           309.0
# 2                                         Cuba            98.0
# 3                                        India            87.0
# 4                                    Guatemala            48.0
# 5                                     Colombia            40.0
# 6                                      Nigeria            39.0
# 7                                    Nicaragua            20.0
# 8                                        Haiti            14.0
# 9                                        Ghana            12.0
# 10                        Syrian Arab Republic            11.0
# 11                                  Bangladesh             9.0
# 12                               United States             7.0
# 13                                    Cameroon             6.0
# ...

# %%
df_top = df.sort_values(by="SOLICITANTES17", ascending= False).head(10)
df_top
# Out:
#                               COUNTRY  SOLICITANTES13  SOLICITANTES14  \
# 0                            Honduras           530.0          1035.0
# 41  Venezuela, Bolivarian Republic of             1.0            56.0
# 1                         El Salvador           309.0           626.0
# 2                                Cuba            98.0            96.0
# 4                           Guatemala            48.0           108.0
# 8                               Haiti            14.0            25.0
# 12                      United States             7.0            10.0
# 13                           Cameroon             6.0             5.0
# 5                            Colombia            40.0            31.0
# 64                             Israel             0.0             0.0
#
#     SOLICITANTES15  SOLICITANTES16  SOLICITANTES17
# 0           1560.0          4129.0          4272.0
# 41            57.0           361.0          4042.0
# ...

# %%
df_top.to_csv("top_solicitantes.csv", index=False)
